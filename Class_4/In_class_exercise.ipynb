# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns

# %%
dt = pd.read_csv('/Users/jiawenli/Desktop/MBAN_6110T/Class_4/new_data.csv')

# %%
dt = pd.DataFrame(dt)
dt.head(10)
# Out:
#    Unnamed: 0               event_time event_type  product_id  \
# 0           0  2019-11-01 00:00:00 UTC       view     1003461
# 1           1  2019-11-01 00:00:00 UTC       view     5000088
# 2           2  2019-11-01 00:00:01 UTC       view    17302664
# 3           3  2019-11-01 00:00:01 UTC       view     3601530
# 4           4  2019-11-01 00:00:01 UTC       view     1004775
# 5           5  2019-11-01 00:00:01 UTC       view     1306894
# 6           6  2019-11-01 00:00:01 UTC       view     1306421
# 7           7  2019-11-01 00:00:02 UTC       view    15900065
# 8           8  2019-11-01 00:00:02 UTC       view    12708937
# 9           9  2019-11-01 00:00:02 UTC       view     1004258
#
#            category_id              category_code     brand   price  \
# 0  2053013555631882655     electronics.smartphone    xiaomi  489.07
# 1  2053013566100866035  appliances.sewing_machine    janome  293.65
# 2  2053013553853497655                        NaN     creed   28.31
# ...

# %% [markdown]
# Insights from the price column

# %%
dt['price'].describe()
# Out:
# count    1.000000e+07
# mean     2.925741e+02
# std      3.538111e+02
# min      0.000000e+00
# 25%      6.667000e+01
# 50%      1.653100e+02
# 75%      3.654600e+02
# max      2.574070e+03
# Name: price, dtype: float64

# %%
dt.groupby('category_code').describe()
# Out:
#                      Unnamed: 0                                       \
#                           count          mean           std      min
# category_code
# accessories.bag         45538.0  5.128967e+06  2.886887e+06     90.0
# accessories.umbrella      927.0  4.743570e+06  2.803042e+06  19634.0
# accessories.wallet      10496.0  5.016353e+06  2.791958e+06   1504.0
# apparel.belt              671.0  5.372424e+06  2.894566e+06  25068.0
# apparel.costume         44192.0  5.217024e+06  2.907924e+06    259.0
# ...                         ...           ...           ...      ...
# sport.ski                1303.0  4.711002e+06  2.686582e+06  13605.0
# sport.snowboard          1756.0  5.547192e+06  2.803480e+06   3947.0
# sport.tennis             1043.0  5.880677e+06  2.895192e+06  40429.0
# sport.trainer           10350.0  5.051604e+06  2.925560e+06   3242.0
# stationery.cartrige      1922.0  4.940659e+06  2.831344e+06  35730.0
#
# ...

# %%
dt.groupby('category_code')['price'].describe()
# Out:
#                         count        mean         std    min     25%     50%  \
# category_code
# accessories.bag       45538.0   65.168970   99.975629   0.00   21.49   42.17
# accessories.umbrella    927.0   18.733948    2.602477  17.76   17.76   17.76
# accessories.wallet    10496.0   62.284916   54.681362   0.00   36.04   46.33
# apparel.belt            671.0   55.227586   68.199021  15.19   25.74   25.74
# apparel.costume       44192.0   89.013297   45.333493   0.00   51.48   76.96
# ...                       ...         ...         ...    ...     ...     ...
# sport.ski              1303.0  329.580092  232.147943  32.43  192.80  282.89
# sport.snowboard        1756.0  228.108986  137.001943  50.45  118.15  208.50
# sport.tennis           1043.0   77.218552   61.481706   5.92   30.63   57.66
# sport.trainer         10350.0  382.207353  393.070976   0.00  180.42  254.83
# stationery.cartrige    1922.0   27.734277   46.426591   0.00    8.18   12.84
#
# ...

# %% [markdown]
# Check out the brands

# %%
dt.groupby('brand').describe()
# Out:
#                    Unnamed: 0                                         \
#                         count          mean           std        min
# brand
# a-case                 1441.0  5.114335e+06  2.916204e+06     1904.0
# a-derma                  76.0  5.306092e+06  2.715100e+06   189844.0
# a-elita                  34.0  6.131913e+06  2.630563e+06   504858.0
# a-mega                  126.0  5.781535e+06  2.733993e+06   815237.0
# aardwolf                 10.0  3.709612e+06  1.956509e+06  1499310.0
# ...                       ...           ...           ...        ...
# zvezda                    5.0  4.569069e+06  2.461547e+06  1780930.0
# zwerg                     2.0  7.250872e+06  1.755640e+06  6009447.0
# zwilling                  5.0  8.027321e+06  1.043527e+06  7083172.0
# zwillingjahenckels      100.0  6.641179e+06  2.323182e+06  1130506.0
# zyxel                    82.0  4.946946e+06  3.162573e+06   210855.0
#
# ...

# %%
dt.groupby('event_type').describe()
# Out:
#            Unnamed: 0                                                 \
#                 count          mean           std    min         25%
# event_type
# cart         121767.0  4.778071e+06  2.878100e+06   40.0  2182033.50
# purchase     147105.0  4.913800e+06  2.906522e+06  107.0  2272596.00
# view        9731128.0  5.004080e+06  2.886431e+06    0.0  2506704.75
#
#                                              product_id                ...  \
#                   50%         75%        max      count          mean  ...
# event_type                                                             ...
# cart        4793647.0  7168873.00  9999999.0   121767.0  3.066193e+06  ...
# purchase    4989481.0  7328581.00  9999960.0   147105.0  7.071879e+06  ...
# view        5003544.5  7505759.25  9999998.0  9731128.0  1.115874e+07  ...
#
#              price             user_id                              \
#                75%      max      count          mean           std
# event_type
# ...

# %%
dt.groupby('event_type').groups
# Out:
# {'cart': [40, 502, 537, 849, 956, 970, 1072, 1189, 1286, 1363, 1376, 1484, 1576, 1633, 1697, 1745, 1822, 2018, 2049, 2099, 2138, 2188, 2233, 2275, 2307, 2328, 2377, 2397, 2628, 2707, 2814, 2969, 3003, 3087, 3111, 3118, 3142, 3165, 3300, 3539, 3548, 3591, 3743, 3808, 3826, 3979, 4469, 4663, 4678, 4733, 4765, 4944, 5081, 5171, 5295, 5351, 5430, 5651, 5828, 5868, 5907, 6132, 6144, 6206, 6297, 6546, 6621, 6702, 6746, 6811, 6856, 6882, 6943, 6949, 6987, 7067, 7107, 7244, 7388, 7409, 7507, 7800, 8076, 8262, 8489, 8550, 8560, 8656, 9412, 9590, 9592, 9799, 9866, 10019, 10136, 10165, 10419, 10461, 10670, 10841, ...], 'purchase': [107, 168, 707, 811, 939, 942, 1107, 1387, 1490, 1563, 1584, 1626, 1630, 1657, 1735, 1747, 1813, 1934, 1951, 2005, 2008, 2215, 2274, 2309, 2421, 2662, 2792, 2856, 2917, 2974, 3080, 3083, 3093, 3140, 3212, 3289, 3387, 3512, 3723, 3730, 3883, 3949, 3965, 3982, 4025, 4106, 4253, 4467, 4504, 4511, 4605, 4831, 4860, 4987, 5013, 5020, 5154, 5225, 5284, 5289, 5320, 5451, 547
# ...

# %%
dt['event_type'].value_counts()
# Out:
# view        9731128
# purchase     147105
# cart         121767
# Name: event_type, dtype: int64

# %% [markdown]
# Check out how many products were put into the cart and never got purchased

# %%
dt1 = pd.DataFrame(dt[dt['event_type']=='cart'])
dt1.head()
# Out:
#      Unnamed: 0               event_time event_type  product_id  \
# 40           40  2019-11-01 00:00:14 UTC       cart     1005014
# 502         502  2019-11-01 00:03:24 UTC       cart     1801881
# 537         537  2019-11-01 00:03:39 UTC       cart     1005115
# 849         849  2019-11-01 00:05:54 UTC       cart     1002542
# 956         956  2019-11-01 00:06:38 UTC       cart     1004856
#
#              category_id           category_code    brand   price    user_id  \
# 40   2053013555631882655  electronics.smartphone  samsung  503.09  533326659
# 502  2053013554415534427    electronics.video.tv  samsung  488.80  557746614
# 537  2053013555631882655  electronics.smartphone    apple  949.47  565865924
# 849  2053013555631882655  electronics.smartphone    apple  486.80  549256216
# 956  2053013555631882655  electronics.smartphone  samsung  128.42  513645631
#
#                              user_session
# 40   6b928be2-2bce-4640-8296-0efdf2fda22a
# ...

# %%
dt['product_id'] == 1005014
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 9999995    False
# 9999996    False
# 9999997    False
# 9999998    False
# 9999999    False
# Name: product_id, Length: 10000000, dtype: bool

# %%
dt2 = pd.DataFrame(dt[dt['event_type']=='purchase'])
dt2.head()
# Out:
#      Unnamed: 0               event_time event_type  product_id  \
# 107         107  2019-11-01 00:00:41 UTC   purchase    13200605
# 168         168  2019-11-01 00:01:04 UTC   purchase     1005161
# 707         707  2019-11-01 00:04:51 UTC   purchase     1004856
# 811         811  2019-11-01 00:05:34 UTC   purchase    26401669
# 939         939  2019-11-01 00:06:33 UTC   purchase     1801881
#
#              category_id           category_code    brand   price    user_id  \
# 107  2053013557192163841   furniture.bedroom.bed      NaN  566.30  559368633
# 168  2053013555631882655  electronics.smartphone   xiaomi  211.92  513351129
# 707  2053013555631882655  electronics.smartphone  samsung  128.42  562958505
# 811  2053013563651392361                     NaN  lucente  109.66  541854711
# 939  2053013554415534427    electronics.video.tv  samsung  488.80  557746614
#
#                              user_session
# 107  d6034fa2-41fb-4ac0-9051-55ea9fc9147a
# ...

# %%
dt[dt['product_id']==1005014]
# Out:
#          Unnamed: 0               event_time event_type  product_id  \
# 40               40  2019-11-01 00:00:14 UTC       cart     1005014
# 324             324  2019-11-01 00:02:16 UTC       view     1005014
# 626             626  2019-11-01 00:04:12 UTC       view     1005014
# 768             768  2019-11-01 00:05:16 UTC       view     1005014
# 1099           1099  2019-11-01 00:07:32 UTC       view     1005014
# ...             ...                      ...        ...         ...
# 9995368     9995368  2019-11-07 05:04:51 UTC       view     1005014
# 9995904     9995904  2019-11-07 05:05:15 UTC       view     1005014
# 9997160     9997160  2019-11-07 05:06:12 UTC       view     1005014
# 9999802     9999802  2019-11-07 05:08:11 UTC       view     1005014
# 9999858     9999858  2019-11-07 05:08:14 UTC       view     1005014
#
#                  category_id           category_code    brand   price  \
# 40       2053013555631882655  electronics.smartphone  samsung  503.09
# ...

# %%
dt_merge = pd.merge(dt1, dt2, left_on='product_id', right_on='product_id')
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
